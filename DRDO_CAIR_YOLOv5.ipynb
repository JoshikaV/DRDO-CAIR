# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -r requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 17516 (delta 6), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17516/17516), 16.66 MiB | 17.09 MiB/s, done.
# Resolving deltas: 100% (11997/11997), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # small model
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f503cee-018d-4b24-a976-20f2b442efd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f503cee-018d-4b24-a976-20f2b442efd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = 'CAIR_Image1.png'
results = model(img)
results.save()  # saves to runs/detect/exp by default
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp

# %%
img = 'CAIR_Image2.png'
results = model(img)
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp2

# %%
img = 'CAIR_Image3.png'
results = model(img)
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp3

# %%
img = 'CAIR_Image4.png'
results = model(img)
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp4

# %%
ls runs/detect/
# Out:
# exp/  exp2/  exp3/  exp4/

# %%
ls runs/detect/exp3
# Out:
# CAIR_Image3.jpg

# %%
from IPython.display import Image
Image(filename='runs/detect/exp3/CAIR_Image3.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-14-502143836.py in <cell line: 0>()
#       1 from IPython.display import Image
# ----> 2 Image(filename='runs/detect/exp3/CAIR_Image3.png')
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
# !ls runs/detect/exp3/
# Out:
# CAIR_Image3.jpg

# %%
from IPython.display import Image
Image(filename='runs/detect/exp3/CAIR_Image3.jpg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/yolo_outputs

# %%
# !ls runs/detect/
# Out:
# exp  exp2  exp3  exp4

# %%
# !cp -r runs/detect/exp3 /content/drive/MyDrive/yolo_outputs/

# %%
# !cp -r runs/detect/exp /content/drive/MyDrive/yolo_outputs/

# %%
# !cp -r runs/detect/exp2 /content/drive/MyDrive/yolo_outputs/

# %%
# !cp -r runs/detect/exp4 /content/drive/MyDrive/yolo_outputs/

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-216fb1e7-3863-4e6b-8fe9-f09cadb8e9cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-216fb1e7-3863-4e6b-8fe9-f09cadb8e9cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = 'CAIR_Image5.png'
results = model(img)
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp5

# %%
img = 'CAIR_Image6.png'
results = model(img)
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp6

# %%
ls runs/detect/
# Out:
# exp/  exp2/  exp3/  exp4/  exp5/  exp6/

# %%
# !cp -r runs/detect/exp5 /content/drive/MyDrive/yolo_outputs/

# %%
# !cp -r runs/detect/exp6 /content/drive/MyDrive/yolo_outputs/

# %%
img = 'CAIR_Image1.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 223x283 (no detections)
# Speed: 10.3ms pre-process, 338.8ms inference, 3.3ms NMS per image at shape (1, 3, 512, 640)
# <PIL.Image.Image image mode=RGB size=283x223>
# Saved 1 image to runs/detect/exp7

# %%
img = 'CAIR_Image2.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 307x452 1 person, 1 truck
# Speed: 22.8ms pre-process, 463.7ms inference, 5.2ms NMS per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=452x307>
# Saved 1 image to runs/detect/exp8

# %%
img = 'CAIR_Image3.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 307x476 (no detections)
# Speed: 14.0ms pre-process, 335.1ms inference, 2.5ms NMS per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=476x307>
# Saved 1 image to runs/detect/exp9

# %%
img = 'CAIR_Image4.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 216x316 1 person
# Speed: 11.5ms pre-process, 360.1ms inference, 4.4ms NMS per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=316x216>
# Saved 1 image to runs/detect/exp10

# %%
img = 'CAIR_Image5.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 206x344 1 person, 1 bicycle, 1 chair
# Speed: 9.0ms pre-process, 261.2ms inference, 1.4ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=344x206>
# Saved 1 image to runs/detect/exp11

# %%
img = 'CAIR_Image6.png'
results = model(img)
results.print()
results.show()
results.save()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 207x349 (no detections)
# Speed: 9.1ms pre-process, 253.6ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=349x207>
# Saved 1 image to runs/detect/exp12
